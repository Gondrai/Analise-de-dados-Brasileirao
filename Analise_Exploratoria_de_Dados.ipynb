# %% [markdown]
# <a href="https://colab.research.google.com/github/Gondrai/Analise-de-dados-Brasileirao/blob/main/Analise_Exploratoria_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conhecendo a base de dados

# %% [markdown]
# ## Importando bibliotecas

# %%
##importando bibliotecas
import pandas as pd
import json
import seaborn

# %%
brasileirao_2013 = pd.read_csv("team_statistics_brasileirao_2013.csv")
brasileirao_2013.head()
# Out:
#                     equipe  gols  cartao_amarelo  cartao_vermelho  \
# 0              1. Cruzeiro    77              72                4
# 1             2. Santos FC    51              79                3
# 2  3. Athletico Paranaense    65              91                5
# 3             4. Sao Paulo    39              83               10
# 4           5. Atletico MG    49              96                9
#
#    posse_de_bola  passes_certos  disputa_aerea  ranking
# 0           53.7           79.9           16.2     7.08
# 1           49.5           79.5           16.6     6.93
# 2           49.5           71.5           13.9     6.90
# 3           53.9           83.6           12.8     6.86
# 4           51.3           76.0           15.1     6.86
